# %% [markdown]
# # Crawling

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup

import requests
import json

# %%
"""
    The function gets url of html and return soup object of this url.


    :param html_file_name:       String of url
    :type file_path:        str 

    :return:                soup object of this url
    :rtype:                 soup object 
"""
def load_soup_object(html_file_name):
    url = html_file_name
    html = requests.get(url)
    soup = BeautifulSoup(html.content, "html.parser")
    return soup

# %%
"""
    The function gets url of html and return the number of this page.
    for example:
    the url: "https://www.start.umd.edu/gtd/search/Results.aspx?expanded=no&casualties_type=&casualties_max=&success=yes&ob=GTDID&od=desc&page=10&count=1000#results-table"
                                                                                                                                                                                                                                                          ^                              
                                                                                                                                                                                                                                          The number of this page is 10           
    :param url:              String of url
    :type file_path:        str 

    :return:                     The number of this urt
    :rtype:                       int 
"""
def number_of_url(url):
    num_page_index_in_url = url.find("page=")
    index = num_page_index_in_url
    number = ""
    i = 0
    while (i < (len(url)-num_page_index_in_url)):
        if (url[index+5+i] == "&"):
            break
        i = i +1

    for i in range(i):
        number = number + url[index+5+i]
    
    return int(number)

# %%
"""
    The function gets url of html and return list of data.
    Details of the list:
    [
         Region,
         PROVINCE/ADMINISTRATIVE REGION/U.S. STATE,
         LOCATION DETAILS,
    
          ###Attack Information###
          Type of Attack,
          Successful Attack?,
          
          ###Target Information###
          Name of Entity,
          Specific Description,
          Nationality of Target,
          
          ###Additional Information###
          Hostages,
          Ransom,
          Property Damage,
         
          ###Weapon Information###
          Type of Weapon,
          Sub-type of Weapon,
          
          ###Additional Information###
          Suicide Attack?,
    
          ###Perpetrator Group Information###
          Name of Perpetrator Group,
          Sub name of Perpetrator Group,
          Claimed Responsibility,
          
          ###Perpetrator Statistics###
          Number of Perpetrators,
          
          ###Casualty Information###
          Total Number of Fatalities,
          Number of Perpetrator Fatalities,
          Total Number of Injured
    
    ]
    
    :param url:              String of url
    :type file_path:        str 

    :return:                     List of data
    :rtype:                       list 
"""

def more_data(url_address):
    Region = "Unknown"
    Province = "Unknown"
    Location = "Unknown"
              ###Attack Information###
    Type_of_Attack = "Unknown"
    Successful_Attack = "Unknown"
          
          ###Target Information###
    Name_of_Entity = "Unknown"
    Specific_Description = "Unknown"
    Nationality_of_Target = "Unknown"
          
          ###Additional Information###
    Hostages = "Unknown"
    Ransom = "Unknown"
    Property_Damage = "Unknown"
          
          ###Weapon Information###
    Type_of_Weapon = "Unknown"
    Type_of_sub_type = "Unknown"
    if_title_Weapon = False    
          ###Additional Information###
    Suicide_Attack = "Unknown"

          ###Perpetrator Group Information###
    Group_Name = "Unknown"
    Group_Sub_name = "Unknown"
    Claimed_Responsibility = "Unknown"
    if_title_Perpetrator_Group_2 = False
    if_title_Perpetrator_Group_3 = False
    
          ###Perpetrator Statistics###
    Number_of_Perpetrators = "Unknown"
          
          ###Casualty Information###
    Total_Number_of_Fatalities = "Unknown"
    Number_of_Perpetrator_Fatalities = "Unknown"
    Total_Number_of_Injured = "Unknown"

              
    soup = load_soup_object(url_address)
    url2 = soup("div",attrs={"class":"summary-overview"})
    for p in url2[0].find_all('p'):
        category = p.find('span', attrs={'class':'leftHead'}).text
        if (category == "Region:"):   
            Region = p.find('span', attrs={'class':'leftLarge'}).text
        elif (category == "Province/administrativeregion/u.s. state:"):
            Province = p.find('span', attrs={'class':'leftLarge'}).text
        elif (category == "Location Details:" ):
            Location = p.find('span', attrs={'class':'leftLarge'}).text

    url3 = soup("div",attrs={"id":"secondary-right"}) 
    nunber_of_table = 0 
    num_of_rows_in_nunber_of_table_3 = 0
    
    for tbl in url3[0].find_all('table'):
        nunber_of_table = nunber_of_table+1
        end_of_table_3 = True
        for row in tbl("tr"):
                cells = row("td")+row("th")

                if  (len(cells) == 2):
                    if (if_title_Weapon):
                        Type_of_Weapon =  cells[0].get_text().strip()
                        Type_of_sub_type =  cells[1].get_text().strip()
                        if_title_Weapon = False
                    elif(if_title_Perpetrator_Group_2):
                        Group_Name =  cells[0].get_text().strip()
                        Claimed_Responsibility =  cells[1].get_text().strip() 
                        if_title_Perpetrator_Group_2 = False                        
                    elif ( cells[0].get_text().strip()  =="Type of Attack (more)"):
                        Type_of_Attack =  cells[1].get_text().strip()
                    elif ( cells[0].get_text().strip()  =="Successful Attack? (more)"):
                        Successful_Attack =  cells[1].get_text().strip()
                    elif ( cells[0].get_text().strip()  =="Name of Entity"):
                        Name_of_Entity =  cells[1].get_text().strip()
                    elif ( cells[0].get_text().strip()  =="Specific Description"):
                        Specific_Description =  cells[1].get_text().strip()
                    elif ( cells[0].get_text().strip()  =="Nationality of Target"):
                        Nationality_of_Target =  cells[1].get_text().strip()
                    elif ( cells[0].get_text().strip()  =="Hostages"):
                        Hostages =  cells[1].get_text().strip()
                    elif ( cells[0].get_text().strip()  =="Ransom"):
                        Ransom =  cells[1].get_text().strip()
                    elif ( cells[0].get_text().strip()  =="Property Damage"):
                        Property_Damage =  cells[1].get_text().strip()
                    elif ( cells[0].get_text().strip()  =="Suicide Attack?"):
                        Suicide_Attack =  cells[1].get_text().strip()
                    elif ( cells[0].get_text().strip()  =="Number of Perpetrators"):
                        Number_of_Perpetrators =  cells[1].get_text().strip()
                    elif ( cells[0].get_text().strip()  =="Total Number of Fatalities"):
                        Total_Number_of_Fatalities =  cells[1].get_text().strip()
                    elif ( cells[0].get_text().strip()  =="Total Number of Injured"):
                        Total_Number_of_Injured =  cells[1].get_text().strip()
                    elif ( cells[0].get_text().strip()  =="Number of Perpetrator Fatalities"):
                        Number_of_Perpetrator_Fatalities =  cells[1].get_text().strip()
                    elif (cells[0].get_text().strip()  == "Type"):
                        if_title_Weapon = True
                    elif (cells[0].get_text().strip()  == "Group Name"):
                        if_title_Perpetrator_Group_2 = True
                if  (len(cells) == 3):
                    if(if_title_Perpetrator_Group_3):
                        Group_Name =  cells[0].get_text().strip()
                        Group_Sub_name =  cells[1].get_text().strip()
                        Claimed_Responsibility =  cells[2].get_text().strip()
                    elif (cells[0].get_text().strip()  == "Group Name"):
                        if_title_Perpetrator_Group_3 = True
                    
                

    list_from_table = [Region,
            Province,
            Location,
            Type_of_Attack,
            Successful_Attack,
            Name_of_Entity,
            Specific_Description,
            Nationality_of_Target,
            Hostages,
            Ransom,
            Property_Damage,
            Type_of_Weapon,
            Type_of_sub_type,
            Suicide_Attack,
            Group_Name,
            Group_Sub_name,
            Claimed_Responsibility,
            Number_of_Perpetrators,
            Total_Number_of_Fatalities,
            Total_Number_of_Injured,
            Number_of_Perpetrator_Fatalities]  
    for n, i in enumerate(list_from_table):
        if i == "":
            list_from_table[n] = "Unknown"
    return list_from_table

# %%
"""
    The function gets url of the website "GTD" (Global Terrorism Database) and return the database from him.

    :param url:              String of url
    :type file_path:        str 

    :return:                     Database of Global Terrorism
    :rtype:                       DataFrame 
"""

def load_data_of_terrorism(url_address,n_pages):
    ###
    ### YOUR CODE HERE
    ###
    list_of_data = list()
    DATE = list()
    COUNTRY = list()
    CITY = list()
    PERPETRATOR_GROUP = list()
    FATALITIES = list()
    INJURED = list()
    TARGET_TYPE = list()
    links_page = list()
    Region = list()
    Type_of_State = list()
    LOCATION_DETAILS = list()
    
          ###Attack Information###
    Type_of_Attack = list()
    Successful_Attack = list()
          
          ###Target Information###
    Name_of_Entity = list()
    Specific_Description = list()
    Nationality_of_Target = list()
          
          ###Additional Information###
    Hostages = list()
    Ransom = list()
    Property_Damage = list()
    
          ###Weapon Information###
    Type = list()
    Sub_type = list()
          
          ###Additional Information###
    Suicide_Attack = list()
          
          ###Perpetrator Group Information###
    Group_Name_of_Perpetrator_Group = list()
    Group_Sub_Name_of_Perpetrator_Group = list() 
    Claimed_Responsibility = list()
          
         ###Perpetrator Statistics###
    Number_of_Perpetrators = list()       
    
          ###Casualty Information###
    Total_Number_of_Fatalities = list()
    Total_Number_of_Injured = list()
    Number_of_Perpetrator_Fatalities = list()
          
    
    start_url = "https://www.start.umd.edu/gtd/search/Results.aspx" 
    url = url_address
    for i in range(n_pages):
        soup = load_soup_object(url)
        if (i !=0):            
            url2 = soup("div",attrs={"class":"search-bottom-nav screen-only"})
            for a in url2[0].find_all('a'):
                next_url = start_url + a['href']
                num_page_in_next_url = number_of_url(next_url)
                num_page_in_url = number_of_url(url)
                if (num_page_in_next_url > num_page_in_url):
                    links_page.append(next_url)
                    url = next_url
    url = url_address

    for i in range(n_pages):
        time.sleep(5.4)
        if (i ==0):
            soup = load_soup_object(url)
        else:
            soup = load_soup_object(links_page[i-1])
        tbl = soup ("table",attrs={"class":"results"})[0]
        for row in tbl("tr"):
            cells = row("td")
            if  (len(cells)<8):
                continue
            
            try:
                if(len(cells[0].get_text().strip()) == 12):
                    DATE.append(cells[1].get_text().strip())
                    COUNTRY.append(cells[2].get_text().strip())
                    CITY.append(cells[3].get_text().strip())
                    PERPETRATOR_GROUP.append(cells[4].get_text().strip())
                    FATALITIES.append(cells[5].get_text().strip())
                    INJURED.append(cells[6].get_text().strip())
                    TARGET_TYPE.append(cells[7].get_text().strip())
                    list_of_data = more_data( "https://www.start.umd.edu/gtd/search/IncidentSummary.aspx?gtdid=" + cells[0].get_text().strip())
                    Region.append(list_of_data[0])
                    Type_of_State.append(list_of_data[1])
                    LOCATION_DETAILS.append(list_of_data[2])
                    Type_of_Attack.append(list_of_data[3])
                    Successful_Attack.append(list_of_data[4])
                    Name_of_Entity.append(list_of_data[5])
                    Specific_Description.append(list_of_data[6])
                    Nationality_of_Target.append(list_of_data[7])
                    Hostages.append(list_of_data[8])
                    Ransom.append(list_of_data[9])
                    Property_Damage.append(list_of_data[10])
                    Type.append(list_of_data[11])
                    Sub_type.append(list_of_data[12])
                    Suicide_Attack.append(list_of_data[13])
                    Group_Name_of_Perpetrator_Group.append(list_of_data[14])
                    Group_Sub_Name_of_Perpetrator_Group.append(list_of_data[15])   
                    Claimed_Responsibility.append(list_of_data[16])
                    Number_of_Perpetrators.append(list_of_data[17])
                    Total_Number_of_Fatalities.append(list_of_data[18])
                    Total_Number_of_Injured.append(list_of_data[19])
                    Number_of_Perpetrator_Fatalities.append(list_of_data[20])
                    data_frame_of_rerror = pd.DataFrame({"DATE":DATE,
                             "COUNTRY":COUNTRY,
                             "CITY":CITY,
                             "PERPETRATOR GROUP":PERPETRATOR_GROUP,
                             "FATALITIES":FATALITIES,
                             "INJURED":INJURED,
                             "TARGET TYPE":TARGET_TYPE,
                             "Region":Region,
                             "PROVINCE/ADMINISTRATIVE REGION/U.S. STATE":Type_of_State,
                             "LOCATION DETAILS":LOCATION_DETAILS,
                             "Type of Attack":Type_of_Attack,
                             "Successful Attack?":Successful_Attack,
                             "Name of Entity":Name_of_Entity,
                             "Specific Description":Specific_Description,
                             "Nationality of Target":Nationality_of_Target,
                             "Hostages":Hostages,
                             "Ransom":Ransom,
                             "Property Damage":Property_Damage,
                             "Weapon Type":Type,
                             "Weapon Sub_type":Sub_type,
                             "Suicide_Attack":Suicide_Attack,
                             "Group Name of Perpetrator Group":Group_Name_of_Perpetrator_Group,
                             "Group Sub Name of Perpetrator Group":Group_Sub_Name_of_Perpetrator_Group,  
                             "Claimed Responsibility":Claimed_Responsibility,
                             "Number of Perpetrators":Number_of_Perpetrators,
                             "Total Number of Fatalities":Total_Number_of_Fatalities,
                             "Number of Perpetrator Fatalities":Number_of_Perpetrator_Fatalities,
                             "Total Number of Injured":Total_Number_of_Injured
                            })
            except:
                print("try ID:  ",cells[0].get_text().strip())
                print("The url is:  ",links_page[i-1])


                
    return data_frame_of_rerror

# %%
url  = "https://www.start.umd.edu/gtd/search/Results.aspx?expanded=no&casualties_type=b&casualties_max=&dtp2=all&success=yes&region=10&ob=GTDID&od=desc&page=1&count=100#results-table"


print("Start Crawling")
df = load_data_of_terrorism(url,300)
df.to_csv('data_of_terrorism.csv')
print(type(df))
df
# Out:
# Start Crawling
# <class 'pandas.core.frame.DataFrame'>
#                     CITY                   COUNTRY  \
# 0                Baghdad                      Iraq
# 1                   Nada                      Iraq
# 2                 Tabqah                     Syria
# 3          Ataq district                     Yemen
# 4                 Mahfad                     Yemen
# 5               Fallujah                      Iraq
# 6              Nasiriyah                      Iraq
# 7      Al-Faris district                      Iraq
# 8                   Taji                      Iraq
# 9                   Dali                     Yemen
# 10        Hatra district                      Iraq
# 11                 Mosul                      Iraq
# 12               Karbala                      Iraq
# 13               Baghdad                      Iraq
# 14               Samarra                      Iraq
# 15                Kirkuk                      Iraq
# 16              Hudaydah                     Yemen
# 17                 Badir                      Iraq
# 18            Qabr Umayr                     Egypt
# 19               Unknown                     Syria
# 20                 Anoud              Saudi Arabia
# 21               Baghdad                      Iraq
# 22               Baghdad                      Iraq
# 23               Baghdad                      Iraq
# 24              Dhuluiya                      Iraq
# 25          Bayt Maghari                     Yemen
# 26               Baghdad                      Iraq
# 27              Ashkelon                    Israel
# 28                   Zab                      Iraq
# 29                Kashaf                      Iraq
# ...                  ...                       ...
# 29970              Mosul                      Iraq
# 29971           Tarmiyah                      Iraq
# 29972     Baiji district                      Iraq
# 29973     Baiji district                      Iraq
# 29974            Baghdad                      Iraq
# 29975             Kirkuk                      Iraq
# 29976          Abkaziyah                      Iraq
# 29977            Baghdad                      Iraq
# 29978            Samarra                      Iraq
# 29979            Hawijah                      Iraq
# 29980            Hawijah                      Iraq
# 29981              Shaab                      Iraq
# 29982              Mosul                      Iraq
# 29983      Damt district                     Yemen
# 29984            Unknown                     Yemen
# 29985               Aden                     Yemen
# 29986            Baqubah                      Iraq
# 29987            Unknown                      Iraq
# 29988            Baqubah                      Iraq
# 29989             Khalis                      Iraq
# 29990     Matun district                     Yemen
# 29991         Khan Yunis  West Bank and Gaza Strip
# 29992            Huwwara  West Bank and Gaza Strip
# 29993              Baiji                      Iraq
# 29994            Unknown                     Yemen
# 29995              Ahwar                     Yemen
# 29996              Jlala                   Lebanon
# 29997             Yizrab                      Iraq
# 29998         Al-Siniyah                      Iraq
# 29999              Mosul                      Iraq
#
#                       Claimed Responsibility        DATE FATALITIES  \
# 0                                         No  2019-12-31          0
# 1                                         No  2019-12-30          1
# 2                                         No  2019-12-31          3
# 3                                         No  2019-12-31    Unknown
# 4                                         No  2019-12-30          1
# 5                                         No  2019-12-30          5
# 6                                         No  2019-12-30          1
# 7                                         No  2019-12-30          0
# 8                                         No  2019-12-29          0
# 9                                         No  2019-12-29          7
# 10                                        No  2019-12-28          2
# 11                                        No  2019-12-28          6
# 12                                        No  2019-12-28          1
# 13                                        No  2019-12-24          0
# 14                                        No  2019-12-27          0
# 15                                        No  2019-12-27          1
# 16                                        No  2019-12-26          0
# 17                                        No  2019-12-26          0
# 18     Yes (Confirmed: Unknown; Mode: Video)  2019-12-25          1
# 19                                        No  2019-12-25          0
# 20                                        No  2019-12-25          2
# 21                                        No  2019-12-25          0
# 22                                        No  2019-12-25          0
# 23                                        No  2019-12-25          0
# 24                                        No  2019-12-25          3
# 25                                        No  2019-12-25          0
# 26                                        No  2019-12-25          0
# 27                                        No  2019-12-25          0
# 28                                        No  2019-12-24          0
# 29                                        No  2019-12-24          2
# ...                                      ...         ...        ...
# 29970                                     No  2013-11-02          0
# 29971                                     No  2013-11-02          0
# 29972                                     No  2013-11-02          0
# 29973                                     No  2013-11-02          1
# 29974                                     No  2013-11-02          1
# 29975                                     No  2013-11-01          0
# 29976                                     No  2013-11-01          2
# 29977                                     No  2013-11-01          0
# 29978                                     No  2013-11-01          1
# 29979                                     No  2013-11-01          0
# 29980                                     No  2013-11-01          0
# 29981                                     No  2013-11-01          0
# 29982                                     No  2013-11-01          1
# 29983                                     No  2013-11-01    Unknown
# 29984                                     No  2013-11-01          0
# 29985                                     No  2013-11-01          0
# 29986                                     No  2013-10-31          0
# 29987                                     No  2013-10-31          0
# 29988                                     No  2013-10-31          6
# 29989                                     No  2013-10-31          2
# 29990                                     No  2013-10-31          1
# 29991  Yes (Confirmed: Unknown; Mode: Video)  2013-10-31          2
# 29992                                     No  2013-10-31          0
# 29993                                     No  2013-10-31          1
# 29994                                     No  2013-10-31          0
# 29995                                     No  2013-10-31          3
# 29996                                     No  2013-10-31          0
# 29997                                     No  2013-10-31          1
# 29998                                     No  2013-10-31          1
# 29999                                     No  2013-10-31          1
#
#                    Group Name of Perpetrator Group  \
# 0                                          Unknown
# 1      Islamic State of Iraq and the Levant (ISIL)
# 2      Islamic State of Iraq and the Levant (ISIL)
# 3                                   Al-Islah Party
# 4                       Southern Yemen Separatists
# 5      Islamic State of Iraq and the Levant (ISIL)
# 6                              Iran-backed militia
# 7                                          Unknown
# 8                    Kata'ib Hezbollah (suspected)
# 9                  Houthi extremists (Ansar Allah)
# 10     Islamic State of Iraq and the Levant (ISIL)
# 11     Islamic State of Iraq and the Levant (ISIL)
# 12                                         Unknown
# 13                                         Unknown
# 14     Islamic State of Iraq and the Levant (ISIL)
# 15     Islamic State of Iraq and the Levant (ISIL)
# 16                 Houthi extremists (Ansar Allah)
# 17                                         Unknown
# 18             Sinai Province of the Islamic State
# 19                                         Unknown
# 20                                         Unknown
# 21                                         Unknown
# 22                                         Unknown
# 23                                         Unknown
# 24     Islamic State of Iraq and the Levant (ISIL)
# 25                 Houthi extremists (Ansar Allah)
# 26                                         Unknown
# 27                 Palestinian Islamic Jihad (PIJ)
# 28                                         Unknown
# 29                                         Unknown
# ...                                            ...
# 29970                                      Unknown
# 29971                                      Unknown
# 29972                                      Unknown
# 29973                                      Unknown
# 29974                                      Unknown
# 29975                                      Unknown
# 29976                                      Unknown
# 29977                                      Unknown
# 29978                                      Unknown
# 29979                                      Unknown
# 29980                                      Unknown
# 29981                                      Unknown
# 29982                                      Unknown
# 29983                                      Unknown
# 29984                                      Unknown
# 29985                                      Unknown
# 29986                                      Unknown
# 29987                                      Unknown
# 29988                                      Unknown
# 29989                                      Unknown
# 29990                                      Unknown
# 29991          Hamas (Islamic Resistance Movement)
# 29992                                      Unknown
# 29993                                      Unknown
# 29994              Houthi extremists (Ansar Allah)
# 29995     Al-Qaida in the Arabian Peninsula (AQAP)
# 29996                                      Unknown
# 29997                                      Unknown
# 29998                                      Unknown
# 29999                                      Unknown
#
#       Group Sub Name of Perpetrator Group Hostages  INJURED  \
# 0                                 Unknown       No        0
# 1                                 Unknown       No        0
# 2                                 Unknown       No        0
# 3                                 Unknown      Yes  Unknown
# 4                                 Unknown       No        3
# 5                                 Unknown       No        0
# 6                                 Unknown       No        0
# 7                                 Unknown      Yes        1
# 8                                 Unknown       No        0
# 9                                 Unknown       No       25
# 10                                Unknown       No        0
# 11                                Unknown       No        0
# 12                                Unknown       No        0
# 13                                Unknown       No        0
# 14                                Unknown       No        0
# 15                                Unknown       No        6
# 16                                Unknown       No        0
# 17                                Unknown       No        1
# 18                                Unknown      Yes        3
# 19                                Unknown       No        5
# 20                                Unknown       No        0
# 21                                Unknown       No        4
# 22                                Unknown       No        3
# 23                                Unknown       No        2
# 24                                Unknown       No        4
# 25                                Unknown       No  Unknown
# 26                                Unknown       No        4
# 27                                Unknown       No        0
# 28                                Unknown       No        3
# 29                                Unknown       No        5
# ...                                   ...      ...      ...
# 29970                             Unknown       No        4
# 29971                             Unknown       No        2
# 29972                             Unknown       No        4
# 29973                             Unknown       No        0
# 29974                             Unknown       No        0
# 29975                             Unknown       No        2
# 29976                             Unknown       No        6
# 29977                             Unknown       No        5
# 29978                             Unknown       No        4
# 29979                             Unknown       No        0
# 29980                             Unknown       No        0
# 29981                             Unknown       No        0
# 29982                             Unknown       No        0
# 29983                             Unknown       No  Unknown
# 29984                             Unknown       No        1
# 29985                             Unknown       No        0
# 29986                             Unknown       No        2
# 29987                             Unknown      Yes  Unknown
# 29988                             Unknown       No        1
# 29989                             Unknown       No        5
# 29990                             Unknown       No        0
# 29991         Ezzedine al-Qassam Brigades       No        6
# 29992                             Unknown       No        0
# 29993                             Unknown       No        1
# 29994                             Unknown       No        0
# 29995                             Unknown       No        3
# 29996                             Unknown       No        0
# 29997                             Unknown       No        0
# 29998                             Unknown       No        0
# 29999                             Unknown       No        2
#
#                                         LOCATION DETAILS  \
# 0          The incident occurred along Palestine Street.
# 1                                                Unknown
# 2                                                Unknown
# 3                                                Unknown
# 4                                                Unknown
# 5      The incident occurred in the Nuaimiya neighbor...
# 6                                                Unknown
# 7                                                Unknown
# 8                                                Unknown
# 9           The incident occurred in the soccer stadium.
# 10                                               Unknown
# 11                                               Unknown
# 12        The incident occurred in Al-Amel neighborhood.
# 13     The incident occurred in the Babil area of the...
# 14              The incident occurred south of the city.
# 15                 The incident occurred at the K1 base.
# 16                                               Unknown
# 17                                               Unknown
# 18                                               Unknown
# 19                                               Unknown
# 20                    The incident occurred near Dammam.
# 21     The incident occurred in the Shaad area of the...
# 22     The incident occurred in the Malef area of the...
# 23     The incident occurred in the Amin area of the ...
# 24                                               Unknown
# 25           The incident occurred in the Hays district.
# 26     The incident occurred in the Sadr City area of...
# 27                                               Unknown
# 28                                               Unknown
# 29                                               Unknown
# ...                                                  ...
# 29970          Incident occurred in the Al-Qayarah area.
# 29971                                            Unknown
# 29972                                            Unknown
# 29973                                            Unknown
# 29974    Incident occurred in the Azamiyah neighborhood.
# 29975         Incident occurred in the Al-Mamdudah area.
# 29976        Incident occurred at a security checkpoint.
# 29977            Incident occurred in the Al-Iskan area.
# 29978                                            Unknown
# 29979            Incident occurred in the Al-Riyad area.
# 29980      Incident occurred in the Al-Saduniyah village
# 29981                                            Unknown
# 29982  Incident occurred in the Hay Al-Zahra area nea...
# 29983                                            Unknown
# 29984                                            Unknown
# 29985  Incident occurred in the Khormaksar neighborho...
# 29986                                            Unknown
# 29987  Incident occurred in the Al-Ahdab oilfield in ...
# 29988  Incident occurred in the Hay al-Mustafa area o...
# 29989                                            Unknown
# 29990                                            Unknown
# 29991                                            Unknown
# 29992                                            Unknown
# 29993                                            Unknown
# 29994                                            Unknown
# 29995                                            Unknown
# 29996                                            Unknown
# 29997                                            Unknown
# 29998                                            Unknown
# 29999                                            Unknown
#
#                  ...                                  Region  \
# 0                ...              Middle East & North Africa
# 1                ...              Middle East & North Africa
# 2                ...              Middle East & North Africa
# 3                ...              Middle East & North Africa
# 4                ...              Middle East & North Africa
# 5                ...              Middle East & North Africa
# 6                ...              Middle East & North Africa
# 7                ...              Middle East & North Africa
# 8                ...              Middle East & North Africa
# 9                ...              Middle East & North Africa
# 10               ...              Middle East & North Africa
# 11               ...              Middle East & North Africa
# 12               ...              Middle East & North Africa
# 13               ...              Middle East & North Africa
# 14               ...              Middle East & North Africa
# 15               ...              Middle East & North Africa
# 16               ...              Middle East & North Africa
# 17               ...              Middle East & North Africa
# 18               ...              Middle East & North Africa
# 19               ...              Middle East & North Africa
# 20               ...              Middle East & North Africa
# 21               ...              Middle East & North Africa
# 22               ...              Middle East & North Africa
# 23               ...              Middle East & North Africa
# 24               ...              Middle East & North Africa
# 25               ...              Middle East & North Africa
# 26               ...              Middle East & North Africa
# 27               ...              Middle East & North Africa
# 28               ...              Middle East & North Africa
# 29               ...              Middle East & North Africa
# ...              ...                                     ...
# 29970            ...              Middle East & North Africa
# 29971            ...              Middle East & North Africa
# 29972            ...              Middle East & North Africa
# 29973            ...              Middle East & North Africa
# 29974            ...              Middle East & North Africa
# 29975            ...              Middle East & North Africa
# 29976            ...              Middle East & North Africa
# 29977            ...              Middle East & North Africa
# 29978            ...              Middle East & North Africa
# 29979            ...              Middle East & North Africa
# 29980            ...              Middle East & North Africa
# 29981            ...              Middle East & North Africa
# 29982            ...              Middle East & North Africa
# 29983            ...              Middle East & North Africa
# 29984            ...              Middle East & North Africa
# 29985            ...              Middle East & North Africa
# 29986            ...              Middle East & North Africa
# 29987            ...              Middle East & North Africa
# 29988            ...              Middle East & North Africa
# 29989            ...              Middle East & North Africa
# 29990            ...              Middle East & North Africa
# 29991            ...              Middle East & North Africa
# 29992            ...              Middle East & North Africa
# 29993            ...              Middle East & North Africa
# 29994            ...              Middle East & North Africa
# 29995            ...              Middle East & North Africa
# 29996            ...              Middle East & North Africa
# 29997            ...              Middle East & North Africa
# 29998            ...              Middle East & North Africa
# 29999            ...              Middle East & North Africa
#
#                                     Specific Description Successful Attack?  \
# 0                             Residence of Tribal Leader                Yes
# 1                                                   Post                Yes
# 2                                              Civilians                Yes
# 3      Oil Office General Director: Al-Khader Ali Sal...                Yes
# 4                                                Vehicle                Yes
# 5                                                 School                Yes
# 6                              Protestor: Ali Al-Khafaji                Yes
# 7                        Civilian: Sheikh Amer al-Mutlaq                Yes
# 8                                              Camp Taji                Yes
# 9                                                 Parade                Yes
# 10                                             Civilians                Yes
# 11                                          Headquarters                 No
# 12                      Commissioner: Ali Ibrahim Yassin                Yes
# 13                                 Protestor: Awas Fadel                Yes
# 14                                                  City                 No
# 15                                               K1 Base                Yes
# 16                                           Grain Store                Yes
# 17                                             Civilians                Yes
# 18                                             Residence                Yes
# 19                                             Civilians                Yes
# 20                                             Civilians                 No
# 21                                                Market                Yes
# 22                                             Civilians                Yes
# 23                                             Civilians                Yes
# 24                                               Outpost                Yes
# 25                                            Residences                Yes
# 26                                          Soccer Field                Yes
# 27                                                  City                 No
# 28                                                Patrol                Yes
# 29                                             Personnel                Yes
# ...                                                  ...                ...
# 29970                                           Officers                Yes
# 29971                                             Patrol                Yes
# 29972                                          Civilians                Yes
# 29973                               Leader: Hatim Khalaf                Yes
# 29974                                           Employee                Yes
# 29975                                             Patrol                Yes
# 29976                                         Checkpoint                Yes
# 29977                                              Store                Yes
# 29978                                             Patrol                Yes
# 29979                                            Officer                Yes
# 29980                                            Officer                Yes
# 29981                         Police Chief: Imad Murshid                Yes
# 29982                                             Patrol                Yes
# 29983                                       Headquarters                Yes
# 29984                                       Headquarters                Yes
# 29985                                       Headquarters                 No
# 29986                                   House of Officer                Yes
# 29987                      Al-Adhab Oil Field: Oil Tower                Yes
# 29988                                               Park                Yes
# 29989                                          Civilians                Yes
# 29990                             Head: Salih Bin-Nas'ah                Yes
# 29991                                         Checkpoint                Yes
# 29992                                                Bus                Yes
# 29993                                         Checkpoint                Yes
# 29994                                         Checkpoint                 No
# 29995                           111th Brigade Checkpoint                Yes
# 29996                             Intelligence Checkpost                Yes
# 29997                                            Vehicle                Yes
# 29998                                     Militia Member                Yes
# 29999                                             Patrol                Yes
#
#       Suicide_Attack                                        TARGET TYPE  \
# 0                 No                        Private Citizens & Property
# 1                 No                                           Military
# 2                 No                        Private Citizens & Property
# 3                 No                               Government (General)
# 4                 No                                           Military
# 5                 No                            Educational Institution
# 6                 No                        Private Citizens & Property
# 7                 No  Private Citizens & Property,Private Citizens &...
# 8                 No                                           Military
# 9                 No  Military,Terrorists/Non-state Militia,Private ...
# 10                No                        Private Citizens & Property
# 11                No                                           Military
# 12                No                               Government (General)
# 13                No                        Private Citizens & Property
# 14                No                        Private Citizens & Property
# 15                No                                           Military
# 16                No                                                NGO
# 17                No                        Private Citizens & Property
# 18                No                        Private Citizens & Property
# 19                No                        Private Citizens & Property
# 20                No                        Private Citizens & Property
# 21                No                        Private Citizens & Property
# 22                No                        Private Citizens & Property
# 23                No                        Private Citizens & Property
# 24                No                                  Military,Military
# 25                No                        Private Citizens & Property
# 26                No                        Private Citizens & Property
# 27                No                        Private Citizens & Property
# 28                No                                           Military
# 29                No                                           Military
# ...              ...                                                ...
# 29970             No                                             Police
# 29971             No                                             Police
# 29972             No                        Private Citizens & Property
# 29973             No                       Terrorists/Non-state Militia
# 29974             No                               Government (General)
# 29975             No                                           Military
# 29976             No                       Terrorists/Non-state Militia
# 29977             No                                           Business
# 29978             No                                             Police
# 29979             No                                             Police
# 29980             No                                             Police
# 29981             No                                             Police
# 29982             No                                           Military
# 29983             No                                           Military
# 29984             No                                           Military
# 29985             No                               Government (General)
# 29986             No                                             Police
# 29987             No                                          Utilities
# 29988             No                        Private Citizens & Property
# 29989             No                 Police,Private Citizens & Property
# 29990             No                        Private Citizens & Property
# 29991             No                                           Military
# 29992             No                                     Transportation
# 29993             No                       Terrorists/Non-state Militia
# 29994             No                                           Military
# 29995             No                                           Military
# 29996             No                                           Military
# 29997             No                                             Police
# 29998             No                       Terrorists/Non-state Militia
# 29999             No                                           Military
#
#       Total Number of Fatalities Total Number of Injured  \
# 0                              0                       0
# 1                              1                       0
# 2                              3                       0
# 3                        Unknown                 Unknown
# 4                              1                       3
# 5                              5                       0
# 6                              1                       0
# 7                              0                       1
# 8                              0                       0
# 9                              7                      25
# 10                             2                       0
# 11                             6                       0
# 12                             1                       0
# 13                             0                       0
# 14                             0                       0
# 15                             1                       6
# 16                             0                       0
# 17                             0                       1
# 18                             1                       3
# 19                             0                       5
# 20                             2                       0
# 21                             0                       4
# 22                             0                       3
# 23                             0                       2
# 24                             3                       4
# 25                             0                 Unknown
# 26                             0                       4
# 27                             0                       0
# 28                             0                       3
# 29                             2                       5
# ...                          ...                     ...
# 29970                          0                       4
# 29971                          0                       2
# 29972                          0                       4
# 29973                          1                       0
# 29974                          1                       0
# 29975                          0                       2
# 29976                          2                       6
# 29977                          0                       5
# 29978                          1                       4
# 29979                          0                       0
# 29980                          0                       0
# 29981                          0                       0
# 29982                          1                       0
# 29983                    Unknown                 Unknown
# 29984                          0                       1
# 29985                          0                       0
# 29986                          0                       2
# 29987                          0                 Unknown
# 29988                          6                       1
# 29989                          2                       5
# 29990                          1                       0
# 29991                          2                       6
# 29992                          0                       0
# 29993                          1                       1
# 29994                          0                       0
# 29995                          3                       3
# 29996                          0                       0
# 29997                          1                       0
# 29998                          1                       0
# 29999                          1                       2
#
#                        Type of Attack  \
# 0                   Bombing/Explosion
# 1                             Unknown
# 2                             Unknown
# 3      Facility/Infrastructure Attack
# 4                       Armed Assault
# 5                   Bombing/Explosion
# 6                       Armed Assault
# 7         Hostage Taking (Kidnapping)
# 8                   Bombing/Explosion
# 9                   Bombing/Explosion
# 10                      Armed Assault
# 11                            Unknown
# 12                      Assassination
# 13                      Armed Assault
# 14                            Unknown
# 15                  Bombing/Explosion
# 16                  Bombing/Explosion
# 17                  Bombing/Explosion
# 18        Hostage Taking (Kidnapping)
# 19                  Bombing/Explosion
# 20                  Bombing/Explosion
# 21                  Bombing/Explosion
# 22                  Bombing/Explosion
# 23                  Bombing/Explosion
# 24                      Armed Assault
# 25                  Bombing/Explosion
# 26                  Bombing/Explosion
# 27                  Bombing/Explosion
# 28                  Bombing/Explosion
# 29                  Bombing/Explosion
# ...                               ...
# 29970               Bombing/Explosion
# 29971               Bombing/Explosion
# 29972               Bombing/Explosion
# 29973               Bombing/Explosion
# 29974               Bombing/Explosion
# 29975                   Armed Assault
# 29976                   Armed Assault
# 29977               Bombing/Explosion
# 29978               Bombing/Explosion
# 29979               Bombing/Explosion
# 29980               Bombing/Explosion
# 29981               Bombing/Explosion
# 29982               Bombing/Explosion
# 29983                         Unknown
# 29984                         Unknown
# 29985               Bombing/Explosion
# 29986               Bombing/Explosion
# 29987  Facility/Infrastructure Attack
# 29988               Bombing/Explosion
# 29989               Bombing/Explosion
# 29990                   Assassination
# 29991               Bombing/Explosion
# 29992                   Armed Assault
# 29993                   Armed Assault
# 29994                   Armed Assault
# 29995                   Armed Assault
# 29996               Bombing/Explosion
# 29997               Bombing/Explosion
# 29998                         Unknown
# 29999                   Armed Assault
#
#                                  Weapon Sub_type                Weapon Type
# 0                         Unknown Explosive Type  Explosives/Bombs/Dynamite
# 1                                        Unknown                    Unknown
# 2                                        Unknown                    Unknown
# 3                                        Unknown                    Unknown
# 4                               Automatic Weapon                   Firearms
# 5                         Unknown Explosive Type  Explosives/Bombs/Dynamite
# 6                               Unknown Gun Type                   Firearms
# 7                               Automatic Weapon                   Firearms
# 8      Projectile (rockets, mortars, RPGs, etc.)  Explosives/Bombs/Dynamite
# 9      Projectile (rockets, mortars, RPGs, etc.)  Explosives/Bombs/Dynamite
# 10                              Unknown Gun Type                   Firearms
# 11                                       Unknown                    Unknown
# 12                              Unknown Gun Type                   Firearms
# 13                              Unknown Gun Type                   Firearms
# 14                                       Unknown                    Unknown
# 15     Projectile (rockets, mortars, RPGs, etc.)  Explosives/Bombs/Dynamite
# 16     Projectile (rockets, mortars, RPGs, etc.)  Explosives/Bombs/Dynamite
# 17                        Unknown Explosive Type  Explosives/Bombs/Dynamite
# 18                              Automatic Weapon                   Firearms
# 19                                       Vehicle  Explosives/Bombs/Dynamite
# 20                                       Vehicle  Explosives/Bombs/Dynamite
# 21                        Unknown Explosive Type  Explosives/Bombs/Dynamite
# 22                        Unknown Explosive Type  Explosives/Bombs/Dynamite
# 23                                       Vehicle  Explosives/Bombs/Dynamite
# 24                              Automatic Weapon                   Firearms
# 25     Projectile (rockets, mortars, RPGs, etc.)  Explosives/Bombs/Dynamite
# 26                                       Vehicle  Explosives/Bombs/Dynamite
# 27     Projectile (rockets, mortars, RPGs, etc.)  Explosives/Bombs/Dynamite
# 28                        Unknown Explosive Type  Explosives/Bombs/Dynamite
# 29                        Unknown Explosive Type  Explosives/Bombs/Dynamite
# ...                                          ...                        ...
# 29970                     Unknown Explosive Type  Explosives/Bombs/Dynamite
# 29971                     Unknown Explosive Type  Explosives/Bombs/Dynamite
# 29972                     Unknown Explosive Type  Explosives/Bombs/Dynamite
# 29973                                    Vehicle  Explosives/Bombs/Dynamite
# 29974                                    Vehicle  Explosives/Bombs/Dynamite
# 29975                           Unknown Gun Type                   Firearms
# 29976                           Unknown Gun Type                   Firearms
# 29977                     Unknown Explosive Type  Explosives/Bombs/Dynamite
# 29978                     Unknown Explosive Type  Explosives/Bombs/Dynamite
# 29979                     Unknown Explosive Type  Explosives/Bombs/Dynamite
# 29980                     Unknown Explosive Type  Explosives/Bombs/Dynamite
# 29981                     Unknown Explosive Type  Explosives/Bombs/Dynamite
# 29982                     Unknown Explosive Type  Explosives/Bombs/Dynamite
# 29983                                    Unknown                    Unknown
# 29984                                    Unknown                    Unknown
# 29985                     Unknown Explosive Type  Explosives/Bombs/Dynamite
# 29986                     Unknown Explosive Type  Explosives/Bombs/Dynamite
# 29987                           Unknown Gun Type                   Firearms
# 29988                     Unknown Explosive Type  Explosives/Bombs/Dynamite
# 29989                                    Vehicle  Explosives/Bombs/Dynamite
# 29990                                    Unknown                    Unknown
# 29991                     Unknown Explosive Type  Explosives/Bombs/Dynamite
# 29992                           Unknown Gun Type                   Firearms
# 29993                           Unknown Gun Type                   Firearms
# 29994                           Unknown Gun Type                   Firearms
# 29995                           Unknown Gun Type                   Firearms
# 29996                             Remote Trigger  Explosives/Bombs/Dynamite
# 29997                     Unknown Explosive Type  Explosives/Bombs/Dynamite
# 29998                                    Unknown                    Unknown
# 29999                           Unknown Gun Type                   Firearms
#
# [30000 rows x 28 columns]

# %%
df.shape
# Out:
# (30000, 28)
